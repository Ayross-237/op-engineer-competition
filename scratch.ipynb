# %%
from src.persistence.helpers import *

# %%
get_schools()
id = 2

# %%
get_caterer(id)
# Out:
# 2

# %%
get_menu(2)
# Out:
# [('Spicy Miso Udon', ['DF']),
#  ('Mie Goreng', ['GF', 'DF', 'NF', 'V']),
#  ('Beef Pad Thai', []),
#  ('Lemongrass Grilled Beef and Noodles', ['GF', 'DF', 'NF', 'V'])]

# %%
get_sessions(id)
# Out:
# [(2, 'Tuesday', '16:30:00', '19:30:00')]

# %%
get_students(2)
# Out:
# [(3, ['H', 'V']), (4, [])]
