# %%
from src.persistence.helpers import *

# %%
get_schools()
# Out:
# [(1, "Moreton Bay Boys' College"),
#  (2, 'John Paul College'),
#  (3, 'Indooroopilly State High School'),
#  (4, 'Loreto College')]

# %%
get_menu_for_school(1)
# Out:
# [('Shrimp Fried Rice', ['GF', 'DF']),
#  ('Spaghetti Bolognese + Garlic Bread', ['NF']),
#  ('Sweet and Sour Chicken', ['GF', 'DF', 'NF']),
#  ('Japanese Chicken Curry', ['DF', 'NF', 'V'])]

# %%
get_dietary_counts_for_school(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_dietary_counts_for_school(1)
#
# NameError: name 'get_dietary_counts_for_school' is not defined
